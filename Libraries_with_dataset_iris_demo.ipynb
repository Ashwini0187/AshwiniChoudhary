# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashwini0187/AshwiniChoudhary/blob/main/Libraries_with_dataset_iris_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np



series_data = pd.Series([1,3,5,np.nan, 6,8])
series_data
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# !pip install pandas

# %%
data = pd.date_range("20170101", periods= 6 , freq = 'M')
data
# Out:
# DatetimeIndex(['2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30',
#                '2017-05-31', '2017-06-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
my_datasets = {'cars':["BMW" , "Ferrari" , "Volvo", 'Kia' , "Brazzers" ,'Ford'],'car_nos':[1,2,3,4,5,6]}

df = pd.DataFrame(my_datasets)
df
# Out:
#        cars  car_nos
# 0       BMW        1
# 1   Ferrari        2
# 2     Volvo        3
# 3       Kia        4
# 4  Brazzers        5
# 5      Ford        6

# %%
import pandas as pd
import numpy as np


df = pd.DataFrame(np.random.randn(6,4), index = dates , columns = list("abcd"))
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3668fdba1afb> in <cell line: 5>()
#       3
#       4
# ----> 5 df = pd.DataFrame(np.random.randn(6,4), index = dates , columns = list("abcd"))
#       6 df
#
# NameError: name 'dates' is not defined

# %%
df = pd.DataFrame(np.random.randn(6,4) , index = dates ,columns = list("ABCD"))
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f1ec5d24f6c1> in <cell line: 1>()
# ----> 1 df = pd.DataFrame(np.random.randn(6,4) , index = dates ,columns = list("ABCD"))
#       2 df
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.0.3
# 1.25.2

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
x_axis = np.array([0,6])
y_axis = np.array([0, 250])

plt.plot(x_axis, y_axis)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plot -1
x=np.array([0,1,2,3])
y=np.array([3,9,8,7])

plt.subplot(2,1,1)
plt.plot(x,y)

#plot -2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(2,1,2)
plt.plot(x,y)

plt.show()

# %%
X = np.array([5,7,8,9,5,4,4,8,6,5,7,85,98,45])

Y = np.array([99,89,47,11,111,96,78,65,25,36 , 48 , 65 , 98 , 100])

plt.scatter(x, y)
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([41,52,20,65])

plt.bar(x,y)
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([41,52,20,65])

plt.title("Company Sales Comparison")
plt.xlabel("Companies")
plt.ylabel("Sales")

plt.bar(x,y,color='green', width = 0.2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y = np.array([25,45,78,15])
_lables = ["A" , "B" , "C" , "D"]
#plt.pie(y,)
plt.pie(y, labels = _lables, startangle = 90)
plt.show()

# %%
y = np.array([25,45,78,15])
_lables = ["A" , "B" , "C" , "D"]
#plt.pie(y,)
myexplode = [0.2,0,0,0]
plt.pie(y, labels = _lables, startangle = 90, explode = myexplode)
plt.show()

# %%
y = np.array([25,45,78,15])
_lables = ["A" , "B" , "C" , "D"]
#plt.pie(y,)
myexplode = [0.2,0,0,0]
plt.pie(y, labels = _lables, startangle = 90, explode = myexplode,shadow = True)
plt.show()

# %%
y = np.array([25,45,78,15])
_lables = ["A" , "B" , "C" , "D"]
mycolors = ["b","r","g","y"]
plt.pie(y , labels = _lables , startangle = 270 ,colors =  mycolors,shadow = True,autopct="%1.2f%%",counterclock=False)
plt.show()

# %%
# !pip install seaborn

# %%
import seaborn as sns
sns.set(style='white')
rs=np.random.RandomState(10)
d=rs.normal(size=100)

sns.histplot(d, kde=True, color='m')
# Out:
# <Axes: ylabel='Count'>

# %%
sns.set(style = 'dark')
fmri = sns.load_dataset("fmri")


sns.lineplot(x = "timepoint" ,
             y = "signal" ,
             hue = 'region' ,
             style = 'event',
             data = fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
#import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the Dataset
df = pd.read_csv("/content/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.shape
# Out:
# (150, 6)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 147  148            6.5           3.0            5.2           2.0
# 40    41            5.0           3.5            1.3           0.3
# 4      5            5.0           3.6            1.4           0.2
# 124  125            6.7           3.3            5.7           2.1
# 105  106            7.6           3.0            6.6           2.1
# 3      4            4.6           3.1            1.5           0.2
# 129  130            7.2           3.0            5.8           1.6
# 38    39            4.4           3.0            1.3           0.2
# 19    20            5.1           3.8            1.5           0.3
# 36    37            5.5           3.5            1.3           0.2
#
#             Species
# 147  Iris-virginica
# 40      Iris-setosa
# 4       Iris-setosa
# 124  Iris-virginica
# 105  Iris-virginica
# 3       Iris-setosa
# 129  Iris-virginica
# 38      Iris-setosa
# 19      Iris-setosa
# ...

# %%
from matplotlib import pyplot as plt
_df_20['SepalWidthCm'].plot(kind='hist', bins=20, title='SepalWidthCm')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_20['SepalWidthCm'].plot(kind='hist', bins=20, title='SepalWidthCm')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_16['Species'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_16, x='PetalLengthCm', y='Species', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-62-892484aebd8a>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(_df_16, x='PetalLengthCm', y='Species', inner='stick', palette='Dark2')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1679             try:
# -> 1680                 x = x.astype(np.complex128)
#    1681             except (TypeError, ValueError):
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1682                 try:
# -> 1683                     x = x.astype(np.float64)
#    1684                 except ValueError as err:
#
# ...

# %%
df.groupby('Species').agg(['mean', 'median'])
# Out:
#                     Id        SepalLengthCm        SepalWidthCm         \
#                   mean median          mean median         mean median
# Species
# Iris-setosa       25.5   25.5         5.006    5.0        3.418    3.4
# Iris-versicolor   75.5   75.5         5.936    5.9        2.770    2.8
# Iris-virginica   125.5  125.5         6.588    6.5        2.974    3.0
#
#                 PetalLengthCm        PetalWidthCm
#                          mean median         mean median
# Species
# Iris-setosa             1.464   1.50        0.244    0.2
# Iris-versicolor         4.260   4.35        1.326    1.3
# Iris-virginica          5.552   5.55        2.026    2.0

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-2f6f6606aa2c> in <cell line: 1>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
#Check for null values
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#DROP
# syntax :
# data.dropna(axis = 0 , inplace =  True)


#FILL
df['SepalLengthCm'].fillna(value = df['SepalLengthCm'].mean(), inplace = True)

# %%
df['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
df.drop_duplicates(inplace = True)

# %%
import seaborn as sns

# %%
plt.hist(df['Species'] , color = 'g')
plt.show()

# %%
sns.histplot(df, x = 'Species')
plt.show()
